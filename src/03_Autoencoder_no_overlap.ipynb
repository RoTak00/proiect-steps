# %%
# extract_5step_windows.py
import os
import pandas as pd
import numpy as np
import scipy.signal as signal

resampled_dir = '../data/kaggle-drdataboston/resampled_subjects'
output_csv = '../data/kaggle-drdataboston/all_5step_windows_no_overlap.csv'
fs = 50
samples_per_step = int(fs * 0.6)

rows = []

for filename in os.listdir(resampled_dir):
    if not filename.endswith('.csv'):
        continue

    filepath = os.path.join(resampled_dir, filename)
    df = pd.read_csv(filepath)

    if 'motionUserAccelerationX.G.' not in df.columns:
        continue

    acc_mag = np.sqrt(
        df['motionUserAccelerationX.G.']**2 +
        df['motionUserAccelerationY.G.']**2 +
        df['motionUserAccelerationZ.G.']**2
    )

    b, a = signal.butter(2, [0.5 / (fs/2), 3.0 / (fs/2)], btype='band')
    acc_filt = signal.filtfilt(b, a, acc_mag)

    peaks, _ = signal.find_peaks(acc_filt, distance=fs*0.4)

    for i in range(0, len(peaks) - 5, 5):
        start = peaks[i]
        end = peaks[i + 5]
        window = acc_filt[start:end]

        if len(window) < 30:
            continue

        window_resampled = signal.resample(window, 100)
        row = [filename] + list(window_resampled)
        rows.append(row)

    print(f"{filename}: {len(rows)} windows total")

# Save to CSV
columns = ['filename'] + [f'f{i}' for i in range(100)]
pd.DataFrame(rows, columns=columns).to_csv(output_csv, index=False)
print(f"✅ Saved all 5-step windows to {output_csv}")
# Out:
# sub58-lw-s1.csv: 68 windows total
# sub92-lw-s2.csv: 130 windows total
# sub93-rp-s1.csv: 201 windows total
# sub56-lw-s2.csv: 256 windows total
# sub43-rp-s2.csv: 317 windows total
# sub32-lw-s2.csv: 380 windows total
# sub20-rp-s2.csv: 451 windows total
# sub38-lw-s1.csv: 540 windows total
# sub26-rp-s1.csv: 608 windows total
# sub79-lw-s2.csv: 678 windows total
# sub21-rp-s2.csv: 748 windows total
# sub33-rp-s1.csv: 813 windows total
# sub37-lw-s1.csv: 884 windows total
# sub20-rp-s1.csv: 948 windows total
# sub40-lw-s1.csv: 1021 windows total
# sub24-lw-s1.csv: 1101 windows total
# sub62-lw-s2.csv: 1155 windows total
# sub31-lw-s2.csv: 1216 windows total
# sub31-rp-s2.csv: 1275 windows total
# sub67-lw-s2.csv: 1333 windows total
# sub13-lw-s1.csv: 1393 windows total
# sub28-rp-s2.csv: 1458 windows total
# sub83-rp-s1.csv: 1514 windows total
# sub83-rp-s2.csv: 1571 windows total
# sub24-lw-s2.csv: 1634 windows total
# sub18-lw-s2.csv: 1704 windows total
# sub82-rp-s2.csv: 1769 windows total
# sub50-rp-s1.csv: 1863 windows total
# sub18-rp-s1.csv: 1945 windows total
# sub43-rp-s1.csv: 2002 windows total
# sub44-lw-s1.csv: 2068 windows total
# sub34-rp-s2.csv: 2133 windows total
# sub81-lw-s1.csv: 2215 windows total
# sub51-lw-s1.csv: 2284 windows total
# sub71-lw-s1.csv: 2354 windows total
# sub25-lw-s1.csv: 2401 windows total
# sub27-lw-s1.csv: 2467 windows total
# sub61-rp-s1.csv: 2526 windows total
# sub12-rp-s2.csv: 2599 windows total
# sub5-rp-s2.csv: 2670 windows total
# sub1-lw-s2.csv: 2729 windows total
# sub49-lw-s2.csv: 2807 windows total
# sub75-rp-s2.csv: 2875 windows total
# sub16-lw-s1.csv: 3315 windows total
# sub8-lw-s1.csv: 3401 windows total
# sub53-rp-s1.csv: 3472 windows total
# sub80-lw-s2.csv: 3527 windows total
# sub83-lw-s1.csv: 3602 windows total
# sub87-lw-s1.csv: 3677 windows total
# sub19-lw-s2.csv: 3749 windows total
# sub63-rp-s1.csv: 3805 windows total
# sub88-rp-s1.csv: 3873 windows total
# sub18-rp-s2.csv: 3947 windows total
# sub60-lw-s2.csv: 4011 windows total
# sub26-lw-s1.csv: 4086 windows total
# sub60-rp-s1.csv: 4129 windows total
# sub75-lw-s1.csv: 4190 windows total
# sub1-rp-s1.csv: 4259 windows total
# sub3-rp-s2.csv: 4322 windows total
# sub22-lw-s1.csv: 4382 windows total
# sub71-rp-s2.csv: 4448 windows total
# sub39-lw-s1.csv: 4511 windows total
# sub9-lw-s1.csv: 4574 windows total
# sub49-rp-s2.csv: 4640 windows total
# sub13-rp-s1.csv: 4700 windows total
# sub77-lw-s1.csv: 4761 windows total
# sub34-lw-s1.csv: 4835 windows total
# sub80-rp-s1.csv: 4886 windows total
# sub5-lw-s2.csv: 4953 windows total
# sub1-rp-s2.csv: 5014 windows total
# sub69-lw-s1.csv: 5103 windows total
# sub55-lw-s1.csv: 5173 windows total
# sub86-rp-s2.csv: 5238 windows total
# sub74-rp-s2.csv: 5280 windows total
# sub67-rp-s1.csv: 5339 windows total
# sub62-lw-s1.csv: 5405 windows total
# sub72-rp-s1.csv: 5464 windows total
# sub48-rp-s1.csv: 5529 windows total
# sub58-rp-s2.csv: 5595 windows total
# sub90-lw-s2.csv: 5659 windows total
# sub78-lw-s1.csv: 5724 windows total
# sub93-lw-s1.csv: 5798 windows total
# sub53-rp-s2.csv: 5857 windows total
# sub84-rp-s1.csv: 5917 windows total
# sub71-lw-s2.csv: 5983 windows total
# sub46-lw-s1.csv: 6049 windows total
# sub46-rp-s2.csv: 6110 windows total
# sub64-rp-s1.csv: 6168 windows total
# sub33-lw-s1.csv: 6239 windows total
# sub79-lw-s1.csv: 6307 windows total
# sub2-rp-s2.csv: 6369 windows total
# sub82-lw-s1.csv: 6446 windows total
# sub2-lw-s2.csv: 6509 windows total
# sub93-lw-s2.csv: 6582 windows total
# sub33-rp-s2.csv: 6640 windows total
# sub16-lw-s2.csv: 6696 windows total
# sub8-lw-s2.csv: 6773 windows total
# sub53-lw-s1.csv: 6843 windows total
# sub25-rp-s2.csv: 6907 windows total
# sub8-rp-s2.csv: 6984 windows total
# sub45-rp-s1.csv: 7062 windows total
# sub15-rp-s1.csv: 7127 windows total
# sub46-rp-s1.csv: 7193 windows total
# sub76-lw-s1.csv: 7245 windows total
# sub36-rp-s1.csv: 7307 windows total
# sub59-lw-s1.csv: 7364 windows total
# sub70-lw-s1.csv: 7430 windows total
# sub30-rp-s2.csv: 7496 windows total
# sub16-rp-s2.csv: 7552 windows total
# sub3-lw-s1.csv: 7556 windows total
# sub27-rp-s2.csv: 7605 windows total
# sub39-lw-s2.csv: 7688 windows total
# sub24-rp-s1.csv: 7761 windows total
# sub91-rp-s2.csv: 7840 windows total
# sub52-lw-s1.csv: 7908 windows total
# sub35-lw-s1.csv: 8035 windows total
# sub14-lw-s1.csv: 8110 windows total
# sub49-lw-s1.csv: 8197 windows total
# sub54-rp-s2.csv: 8255 windows total
# sub87-rp-s1.csv: 8324 windows total
# sub11-lw-s1.csv: 8381 windows total
# sub28-rp-s1.csv: 8441 windows total
# sub20-lw-s1.csv: 8506 windows total
# sub6-rp-s2.csv: 8561 windows total
# sub66-rp-s1.csv: 8617 windows total
# sub82-lw-s2.csv: 8689 windows total
# sub78-rp-s2.csv: 8755 windows total
# sub68-rp-s2.csv: 8817 windows total
# sub51-rp-s1.csv: 8873 windows total
# sub15-lw-s1.csv: 8933 windows total
# sub85-lw-s2.csv: 8992 windows total
# sub57-rp-s1.csv: 9047 windows total
# sub42-lw-s2.csv: 9117 windows total
# sub47-rp-s1.csv: 9174 windows total
# sub66-lw-s1.csv: 9233 windows total
# sub59-rp-s1.csv: 9286 windows total
# sub90-rp-s2.csv: 9342 windows total
# sub21-lw-s1.csv: 9415 windows total
# sub30-rp-s1.csv: 9483 windows total
# sub51-rp-s2.csv: 9543 windows total
# sub38-rp-s1.csv: 9620 windows total
# sub92-rp-s2.csv: 9672 windows total
# sub41-rp-s1.csv: 9746 windows total
# sub90-rp-s1.csv: 9811 windows total
# sub81-rp-s1.csv: 9887 windows total
# sub7-lw-s2.csv: 9955 windows total
# sub14-rp-s2.csv: 10032 windows total
# sub54-rp-s1.csv: 10095 windows total
# sub4-rp-s1.csv: 10172 windows total
# sub2-rp-s1.csv: 10238 windows total
# sub28-lw-s1.csv: 10307 windows total
# sub79-rp-s1.csv: 10374 windows total
# sub21-lw-s2.csv: 10457 windows total
# sub24-rp-s2.csv: 10537 windows total
# sub74-rp-s1.csv: 10575 windows total
# sub65-rp-s2.csv: 10639 windows total
# sub44-rp-s1.csv: 10707 windows total
# sub19-rp-s1.csv: 10775 windows total
# sub86-rp-s1.csv: 10841 windows total
# sub23-rp-s1.csv: 10909 windows total
# sub5-lw-s1.csv: 10977 windows total
# sub74-lw-s1.csv: 11031 windows total
# sub54-lw-s1.csv: 11096 windows total
# sub14-lw-s2.csv: 11178 windows total
# sub22-lw-s2.csv: 11252 windows total
# sub22-rp-s1.csv: 11314 windows total
# sub17-lw-s1.csv: 11377 windows total
# sub51-lw-s2.csv: 11448 windows total
# sub88-lw-s1.csv: 11525 windows total
# sub76-lw-s2.csv: 11578 windows total
# sub14-rp-s1.csv: 11651 windows total
# sub56-lw-s1.csv: 11714 windows total
# sub65-lw-s1.csv: 11788 windows total
# sub23-lw-s2.csv: 11846 windows total
# sub41-lw-s1.csv: 11930 windows total
# sub4-lw-s2.csv: 12008 windows total
# sub60-rp-s2.csv: 12069 windows total
# sub29-lw-s1.csv: 12142 windows total
# sub17-rp-s1.csv: 12204 windows total
# sub10-lw-s2.csv: 12270 windows total
# sub20-lw-s2.csv: 12342 windows total
# sub77-lw-s2.csv: 12399 windows total
# sub52-lw-s2.csv: 12471 windows total
# sub63-lw-s1.csv: 12539 windows total
# sub30-lw-s1.csv: 12616 windows total
# sub26-rp-s2.csv: 12681 windows total
# sub89-rp-s1.csv: 12758 windows total
# sub56-rp-s1.csv: 12819 windows total
# sub49-rp-s1.csv: 12897 windows total
# sub15-rp-s2.csv: 12962 windows total
# sub32-rp-s2.csv: 13024 windows total
# sub10-rp-s1.csv: 13094 windows total
# sub27-lw-s2.csv: 13156 windows total
# sub30-lw-s2.csv: 13222 windows total
# sub64-rp-s2.csv: 13282 windows total
# sub38-rp-s2.csv: 13343 windows total
# sub13-rp-s2.csv: 13415 windows total
# sub67-lw-s1.csv: 13479 windows total
# sub7-rp-s2.csv: 13547 windows total
# sub38-lw-s2.csv: 13606 windows total
# sub7-lw-s1.csv: 13676 windows total
# sub88-rp-s2.csv: 13738 windows total
# sub80-lw-s1.csv: 13794 windows total
# sub76-rp-s1.csv: 13847 windows total
# sub78-lw-s2.csv: 13905 windows total
# sub27-rp-s1.csv: 13964 windows total
# sub81-rp-s2.csv: 14033 windows total
# sub37-rp-s1.csv: 14106 windows total
# sub18-lw-s1.csv: 14179 windows total
# sub39-rp-s1.csv: 14240 windows total
# sub9-rp-s2.csv: 14299 windows total
# sub76-rp-s2.csv: 14351 windows total
# sub85-rp-s1.csv: 14419 windows total
# sub69-rp-s1.csv: 14504 windows total
# sub9-lw-s2.csv: 14566 windows total
# sub62-rp-s2.csv: 14617 windows total
# sub75-lw-s2.csv: 14685 windows total
# sub91-rp-s1.csv: 14755 windows total
# sub10-lw-s1.csv: 14825 windows total
# sub65-lw-s2.csv: 14886 windows total
# sub79-rp-s2.csv: 14955 windows total
# sub89-rp-s2.csv: 15017 windows total
# sub64-lw-s2.csv: 15080 windows total
# sub23-rp-s2.csv: 15144 windows total
# sub23-lw-s1.csv: 15212 windows total
# sub46-lw-s2.csv: 15276 windows total
# sub10-rp-s2.csv: 15342 windows total
# sub4-rp-s2.csv: 15408 windows total
# sub21-rp-s1.csv: 15476 windows total
# sub62-rp-s1.csv: 15543 windows total
# sub40-rp-s1.csv: 15618 windows total
# sub36-lw-s1.csv: 15675 windows total
# sub78-rp-s1.csv: 15751 windows total
# sub54-lw-s2.csv: 15808 windows total
# sub11-rp-s1.csv: 15865 windows total
# sub84-rp-s2.csv: 15916 windows total
# sub35-rp-s1.csv: 15967 windows total
# sub16-rp-s1.csv: 16025 windows total
# sub42-rp-s2.csv: 16081 windows total
# sub31-lw-s1.csv: 16138 windows total
# sub19-lw-s1.csv: 16206 windows total
# sub57-lw-s1.csv: 16259 windows total
# sub32-rp-s1.csv: 16316 windows total
# sub58-rp-s1.csv: 16384 windows total
# sub3-rp-s1.csv: 16444 windows total
# sub15-lw-s2.csv: 16506 windows total
# sub80-rp-s2.csv: 16562 windows total
# sub25-rp-s1.csv: 16611 windows total
# sub67-rp-s2.csv: 16672 windows total
# sub82-rp-s1.csv: 16736 windows total
# sub86-lw-s1.csv: 16806 windows total
# sub31-rp-s1.csv: 16873 windows total
# sub6-lw-s1.csv: 16935 windows total
# sub68-lw-s1.csv: 16998 windows total
# sub87-rp-s2.csv: 17066 windows total
# sub52-rp-s1.csv: 17129 windows total
# sub12-lw-s1.csv: 17191 windows total
# sub43-lw-s2.csv: 17247 windows total
# sub68-rp-s1.csv: 17312 windows total
# sub42-rp-s1.csv: 17373 windows total
# sub22-rp-s2.csv: 17457 windows total
# sub56-rp-s2.csv: 17510 windows total
# sub55-rp-s1.csv: 17580 windows total
# sub53-lw-s2.csv: 17643 windows total
# sub52-rp-s2.csv: 17705 windows total
# sub25-lw-s2.csv: 17772 windows total
# sub61-lw-s1.csv: 17835 windows total
# sub34-lw-s2.csv: 17902 windows total
# sub1-lw-s1.csv: 17971 windows total
# sub71-rp-s1.csv: 18038 windows total
# ✅ Saved all 5-step windows to ../data/kaggle-drdataboston/all_5step_windows_no_overlap.csv

# %%
# train_autoencoder.py
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from tensorflow.keras import layers, models
import joblib

windows_df = pd.read_csv('../data/kaggle-drdataboston/all_5step_windows_no_overlap.csv')
matrix_df = pd.read_csv('../data/kaggle-drdataboston/matrix_5step_no_overlap.csv')

# Match metadata to each window
meta_columns = ['Weight', 'Age', 'Height (CM)', 'gender']
file_columns = [
    'subject_left_waist_session1',
    'subject_right_pocket_session1',
    'subject_left_waist_session2',
    'subject_right_pocket_session2'
]

metadata = []
for filename in windows_df['filename']:
    meta_row = None
    for _, row in matrix_df.iterrows():
        if filename in row[file_columns].values:
            meta_row = row
            break
    if meta_row is None:
        metadata.append([np.nan] * len(meta_columns))
    else:
        metadata.append([meta_row[col] for col in meta_columns])

meta_df = pd.DataFrame(metadata, columns=meta_columns)
data_df = pd.concat([windows_df.drop(columns='filename'), meta_df], axis=1)
data_df.dropna(inplace=True)

X = data_df.iloc[:, :100].values
meta_out = data_df[meta_columns]

# Normalize input
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Autoencoder
latent_dim = 16
input_dim = X.shape[1]

input_layer = layers.Input(shape=(input_dim,))
encoded = layers.Dense(64, activation='relu')(input_layer)
encoded = layers.Dense(32, activation='relu')(encoded)
latent = layers.Dense(latent_dim, activation='relu')(encoded)
decoded = layers.Dense(32, activation='relu')(latent)
decoded = layers.Dense(64, activation='relu')(decoded)
output_layer = layers.Dense(input_dim, activation='linear')(decoded)

autoencoder = models.Model(inputs=input_layer, outputs=output_layer)
autoencoder.compile(optimizer='adam', loss='mse')

autoencoder.fit(X_scaled, X_scaled, epochs=50, batch_size=32, shuffle=True)

# Save encoder model separately
encoder = models.Model(inputs=input_layer, outputs=latent)
encoder.save("step_encoder_5step_no_overlap.keras")
joblib.dump(scaler, "step_scaler_5step_no_overlap.pkl")

print(f"Autoencoder trained and saved as step_encoder_5step_no_overlap.keras")
# Out:
# 2025-03-30 17:07:37.511263: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-03-30 17:07:37.520354: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-03-30 17:07:37.592808: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-03-30 17:07:37.655840: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1743343657.709705   12617 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1743343657.724895   12617 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1743343657.847187   12617 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1743343657.847215   12617 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1743343657.847219   12617 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1743343657.847221   12617 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-03-30 17:07:37.862794: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Epoch 1/50
# 2025-03-30 17:17:23.980029: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# 2802/2802 ━━━━━━━━━━━━━━━━━━━━ 3s 972us/step - loss: 0.3938
# Epoch 2/50
# 2802/2802 ━━━━━━━━━━━━━━━━━━━━ 3s 980us/step - loss: 0.1396
# Epoch 3/50
# 2802/2802 ━━━━━━━━━━━━━━━━━━━━ 3s 959us/step - loss: 0.1780
# Epoch 4/50
# 2802/2802 ━━━━━━━━━━━━━━━━━━━━ 3s 981us/step - loss: 0.1222
# Epoch 5/50
# 2802/2802 ━━━━━━━━━━━━━━━━━━━━ 3s 966us/step - loss: 0.1753
# Epoch 6/50
# 2802/2802 ━━━━━━━━━━━━━━━━━━━━ 3s 961us/step - loss: 0.1118
# Epoch 7/50
# 2802/2802 ━━━━━━━━━━━━━━━━━━━━ 3s 992us/step - loss: 0.0913
# Epoch 8/50
# 2802/2802 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 0.0893
# Epoch 9/50
# 2802/2802 ━━━━━━━━━━━━━━━━━━━━ 3s 979us/step - loss: 0.0870
# Epoch 10/50
# 2802/2802 ━━━━━━━━━━━━━━━━━━━━ 3s 973us/step - loss: 0.0788
# Epoch 11/50
# 2802/2802 ━━━━━━━━━━━━━━━━━━━━ 3s 944us/step - loss: 0.0764
# Epoch 12/50
# 2802/2802 ━━━━━━━━━━━━━━━━━━━━ 3s 981us/step - loss: 0.0770
# Epoch 13/50
# 2802/2802 ━━━━━━━━━━━━━━━━━━━━ 3s 968us/step - loss: 0.0736
# Epoch 14/50
# 2802/2802 ━━━━━━━━━━━━━━━━━━━━ 3s 965us/step - loss: 0.0702
# Epoch 15/50
# 2802/2802 ━━━━━━━━━━━━━━━━━━━━ 3s 993us/step - loss: 0.0696
# Epoch 16/50
# 2802/2802 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 0.0748
# Epoch 17/50
# 2802/2802 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 0.0664
# Epoch 18/50
# 2802/2802 ━━━━━━━━━━━━━━━━━━━━ 3s 979us/step - loss: 0.0796
# Epoch 19/50
# 2802/2802 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 0.0591
# Epoch 20/50
# 2802/2802 ━━━━━━━━━━━━━━━━━━━━ 3s 991us/step - loss: 0.0703
# Epoch 21/50
# 2802/2802 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 0.0842
# Epoch 22/50
# 2802/2802 ━━━━━━━━━━━━━━━━━━━━ 3s 986us/step - loss: 0.0661
# Epoch 23/50
# 2802/2802 ━━━━━━━━━━━━━━━━━━━━ 3s 995us/step - loss: 0.0585
# Epoch 24/50
# 2802/2802 ━━━━━━━━━━━━━━━━━━━━ 3s 975us/step - loss: 0.0657
# Epoch 25/50
# 2802/2802 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 0.0740
# Epoch 26/50
# 2802/2802 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 0.0611
# Epoch 27/50
# 2802/2802 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 0.0569
# Epoch 28/50
# 2802/2802 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 0.0626
# Epoch 29/50
# 2802/2802 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 0.0645
# Epoch 30/50
# 2802/2802 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 0.0692
# Epoch 31/50
# 2802/2802 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 0.0571
# Epoch 32/50
# 2802/2802 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 0.0520
# Epoch 33/50
# 2802/2802 ━━━━━━━━━━━━━━━━━━━━ 3s 990us/step - loss: 0.0514
# Epoch 34/50
# 2802/2802 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 0.0602
# Epoch 35/50
# 2802/2802 ━━━━━━━━━━━━━━━━━━━━ 3s 992us/step - loss: 0.0481
# Epoch 36/50
# 2802/2802 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 0.0557
# Epoch 37/50
# 2802/2802 ━━━━━━━━━━━━━━━━━━━━ 3s 993us/step - loss: 0.0716
# Epoch 38/50
# 2802/2802 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 0.0462
# Epoch 39/50
# 2802/2802 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 0.0511
# Epoch 40/50
# 2802/2802 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 0.1017
# Epoch 41/50
# 2802/2802 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 0.0743
# Epoch 42/50
# 2802/2802 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 0.0515
# Epoch 43/50
# 2802/2802 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 0.0589
# Epoch 44/50
# 2802/2802 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 0.0489
# Epoch 45/50
# 2802/2802 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 0.0529
# Epoch 46/50
# 2802/2802 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 0.0462
# Epoch 47/50
# 2802/2802 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 0.0749
# Epoch 48/50
# 2802/2802 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 0.0477
# Epoch 49/50
# 2802/2802 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 0.0593
# Epoch 50/50
# 2802/2802 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 0.0567
# ✅ Autoencoder trained and saved as step_encoder.keras

# %%
# Out:
# Encoded shape: (342, 16)
# /home/robert/.local/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
